# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/oxford-iit-pets/annotations/annotations/._trimaps
# /kaggle/input/oxford-iit-pets/annotations/annotations/README
# /kaggle/input/oxford-iit-pets/annotations/annotations/test.txt
# /kaggle/input/oxford-iit-pets/annotations/annotations/trainval.txt
# /kaggle/input/oxford-iit-pets/annotations/annotations/list.txt
# /kaggle/input/oxford-iit-pets/annotations/annotations/xmls/staffordshire_bull_terrier_165.xml
# /kaggle/input/oxford-iit-pets/annotations/annotations/xmls/saint_bernard_182.xml
# /kaggle/input/oxford-iit-pets/annotations/annotations/xmls/Birman_151.xml
# /kaggle/input/oxford-iit-pets/annotations/annotations/xmls/British_Shorthair_180.xml
# /kaggle/input/oxford-iit-pets/annotations/annotations/xmls/Birman_153.xml
# /kaggle/input/oxford-iit-pets/annotations/annotations/xmls/British_Shorthair_158.xml
# /kaggle/input/oxford-iit-pets/annotations/annotations/xmls/staffordshire_bull_terrier_118.xml
# ...

# %%
from fastai.vision.all import *

# %%
oxford_files = get_image_files("/kaggle/input/oxford-iit-pets/images")
len(oxford_files)
# Out:
# 7390

# %%
img = PILImage.create(oxford_files[0])
img.show()

img = PILImage.create(oxford_files[1])
img.show()
# Out:
# <Axes: >

# %%
print(oxford_files[0])
p = Path(oxford_files[0])
print(p)
print(p.stem)

breed_name_parts = p.stem.split("_")
print(breed_name_parts)
final_breed_name = " "
length_parts = len(breed_name_parts)-1
for i in range(length_parts):
    final_breed_name += breed_name_parts[i]
    final_breed_name += "_"

print(final_breed_name)
    

name = "BEHOLD OF THE GREATEST HOLIES WE HAVE A VERY BRITISH FISH"
name_parts = name.split(" ")
print(name_parts)
# Out:
# /kaggle/input/oxford-iit-pets/images/images/american_pit_bull_terrier_16.jpg
# /kaggle/input/oxford-iit-pets/images/images/american_pit_bull_terrier_16.jpg
# american_pit_bull_terrier_16
# ['american', 'pit', 'bull', 'terrier', '16']
#  american_pit_bull_terrier_
# ['BEHOLD', 'OF', 'THE', 'GREATEST', 'HOLIES', 'WE', 'HAVE', 'A', 'VERY', 'BRITISH', 'FISH']
